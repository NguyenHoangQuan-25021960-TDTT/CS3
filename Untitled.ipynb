# %%
i = 1
while i <= 5:
    print(i, end = " ")
    i = i + 1
print(" Hoàn Thành")

# %%
n = int(input())
while n <= 0:
    n = int(input())
print(n)

# %%
import math
n = int(input(""))
i = 2
while i <= math.isqrt(n):
    if n % i == 0:
        print(" Khong phai so nguyen to")
        break
        i += 1
else:
    print("So nguyen to")

# %%
print(" Xin Chao")
