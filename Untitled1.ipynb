# %%
import math
n = int(input(""))
i = 2
while i <= math.isqrt(n):
    if n % i == 0:
        print("Khong phai so nguyen to")
        i += 1
        break
    else:
        print(" So nguyen to")
        break
# Out:
#  6
# Khong phai so nguyen to
